# %%
#for main

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install import_ipynb

# %%
cd /content/drive/MyDrive/Colab Notebooks/Fork/BISTelligence
# Out:
# /content/drive/MyDrive/Colab Notebooks/Fork/BISTelligence

# %%
import import_ipynb
import data.preprocessing as dp
import model.models as mm
# Out:
# importing Jupyter notebook from /content/drive/MyDrive/Colab Notebooks/Fork/BISTelligence/data/preprocessing.ipynb
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# importing Jupyter notebook from /content/drive/My Drive/Colab Notebooks/Fork/BISTelligence/model/models.ipynb
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def GetLOF(scaled=True):
  if(scaled):
    train_data, test_data = dp.ScaledData()
  else:
    train_data, test_data = dp.NonScaledData()

  model = mm.LocalOutlierFactor(train_data, test_data)
  return model

# %%
def GetMCD(scaled=True):
  if(scaled):
    train_data, test_data = dp.ScaledData()
  else:
    train_data, test_data = dp.NonScaledData()

  model = mm.MinimumCovarianceDeterminant(train_data, test_data)
  return model

# %%
def GetOCSVM(scaled=True):
  if(scaled):
    train_data, test_data = dp.ScaledData()
  else:
    train_data, test_data = dp.NonScaledData()

  model = mm.OneClassSVM(train_data, test_data)
  return model

# %%
def GetGMM(scaled=True):
  if(scaled):
    train_data, test_data = dp.ScaledData()
  else:
    train_data, test_data = dp.NonScaledData()

  model = mm.GausianMixtureModel(train_data, test_data)
  return model

# %%
def GetIForest(scaled=True):
  if(scaled):
    train_data, test_data = dp.ScaledData()
  else:
    train_data, test_data = dp.NonScaledData()

  model = mm.IsolationForest(train_data, test_data)
  return model

# %%
def GetAE(scaled=True):
  if(scaled):
    train_data, test_data = dp.ScaledData()
  else:
    train_data, test_data = dp.NonScaledData()

  model = mm.AutoEncoder(train_data, test_data)
  return model

# %%
def GetXAI(scaled=True):
  if(scaled):
    train_data, test_data = dp.ScaledData()
  else:
    train_data, test_data = dp.NonScaledData()

  model = mm.XAI(train_data, test_data)
  return model
