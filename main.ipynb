# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
pip install import_ipynb

# %%
cd /content/drive/MyDrive/bistelligence/BIStelligence
# Out:
# /content/drive/MyDrive/bistelligence/BIStelligence

# %%
import import_ipynb
import data.preprocessing as dp
import model.models as mm
# Out:
# importing Jupyter notebook from /content/drive/MyDrive/bistelligence/BIStelligence/data/preprocessing.ipynb
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# importing Jupyter notebook from /content/drive/My Drive/bistelligence/BIStelligence/model/models.ipynb
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
def GetScaledData():
  train_data, test_data = dp.ScaledData()
  return train_data, test_data

# %%
def GetNonScaledData():
  train_data, test_data = dp.PreprocessingData()
  return train_data, test_data

# %%
def GetLOF(scaled=True):
  if(scaled):
    train_data, test_data = GetScaledData()
  else:
    train_data, test_data = GetNonScaledData()

  model = mm.LocalOutlierFactor(train_data, test_data)
  return model

# %%
def GetMCD(scaled=True):
  if(scaled):
    train_data, test_data = GetScaledData()
  else:
    train_data, test_data = GetNonScaledData()

  model = mm.MinimumCovarianceDeterminant(train_data, test_data)
  return model

# %%
def GetOCSVM(scaled=True):
  if(scaled):
    train_data, test_data = GetScaledData()
  else:
    train_data, test_data = GetNonScaledData()

  model = mm.OneClassSVM(train_data, test_data)
  return model

# %%
def GetGMM(scaled=True):
  if(scaled):
    train_data, test_data = GetScaledData()
  else:
    train_data, test_data = GetNonScaledData()

  model = mm.GausianMixtureModel(train_data, test_data)
  return model

# %%
def GetIForest(scaled=True):
  if(scaled):
    train_data, test_data = GetScaledData()
  else:
    train_data, test_data = GetNonScaledData()

  model = mm.IsolationForest(train_data, test_data)
  return model

# %%
def GetAE(scaled=True):
  if(scaled):
    train_data, test_data = GetScaledData()
  else:
    train_data, test_data = GetNonScaledData()

  model = mm.AutoEncoder(train_data, test_data)
  return model

# %%
def ShowHealthIndex():
  pass
